# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("W3(data).csv")
data.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St    2.0    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St    2.0    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St    2.0    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St    3.0    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St    3.0    h  1465000.0     SP  Biggin
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03-09-2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  03-12-2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  04-02-2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  04-02-2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  04-03-2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
prev=data.copy()

# %% [markdown]
# #### 1.Determine the no. of rows and no. of columns in the dataset.

# %%
# computing number of rows 
rows = len(data.axes[0]) 
print("Number of Rows: ", rows) 

# computing number of columns 
cols = len(data.axes[1])
print("Number of Columns: ", cols)
# Out:
# Number of Rows:  23678
# Number of Columns:  21

# %% [markdown]
# ##### 2. Display the datatypes of each column.

# %%
# return the dtype of each column 
result = data.dtypes   
# Print the result 
print(result)
# Out:
# Suburb            object
# Address           object
# Rooms            float64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %% [markdown]
# #### 3. Determine the row indexes of rows having all null values (i.e. empty rows)

# %%
rows_with_NAN=[index for index, row in data.iterrows() if row.isnull().any()]
print(rows_with_NAN)
# Out:
# [0, 1, 3, 5, 7, 8, 9, 10, 12, 13, 15, 16, 17, 19, 20, 21, 22, 23, 26, 27, 28, 29, 31, 32, 34, 35, 37, 40, 41, 42, 46, 47, 48, 49, 51, 53, 54, 55, 56, 61, 63, 65, 66, 70, 75, 76, 77, 78, 79, 80, 81, 85, 88, 90, 92, 93, 94, 95, 96, 97, 98, 100, 102, 103, 106, 108, 111, 112, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 131, 132, 133, 135, 138, 140, 141, 142, 144, 145, 147, 149, 151, 152, 154, 155, 157, 158, 159, 161, 164, 165, 166, 168, 170, 171, 172, 174, 175, 176, 180, 181, 182, 183, 185, 186, 188, 189, 190, 191, 193, 195, 197, 198, 199, 200, 201, 204, 207, 208, 209, 210, 211, 212, 213, 214, 219, 221, 222, 223, 224, 225, 226, 228, 229, 235, 238, 240, 241, 244, 246, 248, 249, 251, 253, 254, 255, 257, 258, 259, 261, 264, 266, 267, 268, 269, 271, 272, 273, 274, 275, 276, 278, 280, 281, 282, 284, 287, 288, 289, 291, 292, 294, 295, 297, 298, 299, 301, 303, 304, 305, 306, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 324, 325, 326, 327, 328, 
# ...

# %% [markdown]
# #### 4. Determine the total number of empty rows and their percentage in whole dataset and remove them.

# %%
#total percentage of empty rows in whole dataset 
per=((data.isnull().sum() / data.shape[0]) * 100.00).round(3)
print(per)
# Out:
# Suburb            0.553
# Address           0.553
# Rooms             0.553
# Type              0.553
# Price            22.308
# Method            0.553
# SellerG           0.553
# Date              0.553
# Distance          0.557
# Postcode          0.557
# Bedroom2         19.478
# Bathroom         19.491
# Car              20.090
# Landsize         26.472
# BuildingArea     57.691
# YearBuilt        51.263
# CouncilArea      33.880
# Lattitude        18.730
# Longtitude       18.730
# Regionname        0.557
# Propertycount     0.557
# dtype: float64

# %%
# dropping column with all null values 
new=data.dropna(axis = 1, how ='all', inplace = True)

# %% [markdown]
# #### 5. Determine the column names having missing values.

# %%
nl=data.isnull().sum()
print("columns name missing values:\n",df5.index.tolist())
# Out:
# columns name missing values:
#  ['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG', 'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude', 'Longtitude', 'Regionname', 'Propertycount']

# %% [markdown]
# #### 6. Determine the missing values and their percentage in each column.

# %%
nl=data.isnull().sum().index.tolist()
for i in df6:
    null_values=data[i].isnull().sum()
    percentage=round(((null_values/data.shape[0])*100),2)
    print(i,"              ",null_values,"             ",     percentage,'%')
# Out:
# Suburb                131               0.55 %
# Address                131               0.55 %
# Rooms                131               0.55 %
# Type                131               0.55 %
# Price                5282               22.31 %
# Method                131               0.55 %
# SellerG                131               0.55 %
# Date                131               0.55 %
# Distance                132               0.56 %
# Postcode                132               0.56 %
# Bedroom2                4612               19.48 %
# Bathroom                4615               19.49 %
# Car                4757               20.09 %
# Landsize                6268               26.47 %
# BuildingArea                13660               57.69 %
# YearBuilt                12138               51.26 %
# CouncilArea                8022               33.88 %
# Lattitude                4435               18.73 %
# Longtitude                4435               18.73 %
# ...

# %% [markdown]
# #### 7. Determine the row indexes having missing values.

# %%
data.index[data.isna().any(axis=1)]
# Out:
# Int64Index([    0,     1,     3,     5,     7,     8,     9,    10,    12,
#                13,
#             ...
#             23668, 23669, 23670, 23671, 23672, 23673, 23674, 23675, 23676,
#             23677],
#            dtype='int64', length=17482)

# %% [markdown]
# #### 8. Determine the missing values and their percentage in each row.

# %%
count=data.apply(lambda x: abs(x.count()-data.shape[1]), axis=1)    
row_id=count.index.tolist()
values=count.values.tolist() #null values
for i in range(len(row_id)):
    if values[i]>0:
        null_values=values[i]
        percentage=round(((null_values/data.shape[1])*100),2)
        print('Row ',row_id[i],' no. of null values =',null_values,'percentage = ',percentage)
# Out:
# Row  0  no. of null values = 3 percentage =  14.29
# Row  1  no. of null values = 2 percentage =  9.52
# Row  3  no. of null values = 3 percentage =  14.29
# Row  5  no. of null values = 2 percentage =  9.52
# Row  7  no. of null values = 1 percentage =  4.76
# Row  8  no. of null values = 2 percentage =  9.52
# Row  9  no. of null values = 2 percentage =  9.52
# Row  10  no. of null values = 2 percentage =  9.52
# Row  12  no. of null values = 1 percentage =  4.76
# Row  13  no. of null values = 1 percentage =  4.76
# Row  15  no. of null values = 9 percentage =  42.86
# Row  16  no. of null values = 9 percentage =  42.86
# Row  17  no. of null values = 2 percentage =  9.52
# Row  19  no. of null values = 9 percentage =  42.86
# Row  20  no. of null values = 1 percentage =  4.76
# Row  21  no. of null values = 9 percentage =  42.86
# Row  22  no. of null values = 9 percentage =  42.86
# Row  23  no. of null values = 2 percentage =  9.52
# ...

# %% [markdown]
# #### 9. Determine the column names having more than 30% missing values and remove them from the dataset.

# %%
for i in data.columns:
    null=round(((data[i].isnull().sum()/data.shape[0])*100),2)
    if null >30:
        print('% of null values in',i,'= ',null)
        #Drop columns having null null value
        data.drop([i],axis=1,inplace=True)
# Out:
# % of null values in BuildingArea =  57.69
# % of null values in YearBuilt =  51.26
# % of null values in CouncilArea =  33.88

# %% [markdown]
# #### 10. Determine the number and percentage of rows having more than 5 missing values. If the percentage of such rows is less than 20% then remove all these rows.

# %%
count=data.apply(lambda x: abs(x.count()-data.shape[1]), axis=1)    
row_id=count.index.tolist()
#null value
values=count.values.tolist() 

for i in range(len(row_id)):
    if values[i]>5:
        null_values=values[i]  #number of null values
        percentage=round(((null_values/data.shape[1])*100),2)
        if percentage<20:
            print('At row number ',row_id[i],' number of null values =',null_values,'percentage= ',percentage)
            print('Removing row number',row_id[i])
            df10.dropna(axis=0,inplace=True)   
else:
    print('No Rows exist with both condition satisfied')
    data.shape
# Out:
# No Rows exist with both condition satisfied

# %% [markdown]
# #### 11. Display the description of data and percentage of missing values still left column wise.

# %%
data.describe(include='object')
# Out:
#            Suburb       Address   Type Method SellerG        Date  \
# count       23547         23547  23547  23547   23547       23547
# unique        336         23108      3      9     330          58
# top     Reservoir  5 Charles St      h      S  Nelson  27-05-2017
# freq          629             5  15760  13660    2374         770
#
#                    Regionname
# count                   23546
# unique                      8
# top     Southern Metropolitan
# freq                     8772

# %%
for i in data.columns:
    null=round(((data[i].isnull().sum()/data.shape[0])*100),2)
    if null >0:
        print('percentage of null values in',i,'= ',null)
# Out:
# percentage of null values in Suburb =  0.55
# percentage of null values in Address =  0.55
# percentage of null values in Rooms =  0.55
# percentage of null values in Type =  0.55
# percentage of null values in Price =  22.31
# percentage of null values in Method =  0.55
# percentage of null values in SellerG =  0.55
# percentage of null values in Date =  0.55
# percentage of null values in Distance =  0.56
# percentage of null values in Postcode =  0.56
# percentage of null values in Bedroom2 =  19.48
# percentage of null values in Bathroom =  19.49
# percentage of null values in Car =  20.09
# percentage of null values in Landsize =  26.47
# percentage of null values in Lattitude =  18.73
# percentage of null values in Longtitude =  18.73
# percentage of null values in Regionname =  0.56
# percentage of null values in Propertycount =  0.56

# %% [markdown]
# #### 12. Considering the 'Price' column as target variable which is to be predicted, how will you treat the missing values? Give a brief explanation and treat the missing values in 'Price' column.

# %%
data.head(7)
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St    2.0    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St    2.0    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St    2.0    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St    3.0    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St    3.0    h  1465000.0     SP  Biggin
# 5  Abbotsford    40 Federation La    3.0    h   850000.0     PI  Biggin
# 6  Abbotsford         55a Park St    4.0    h  1600000.0     VB  Nelson
#
#          Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  03-09-2016       2.5    3067.0       2.0       1.0  1.0     126.0
# 1  03-12-2016       2.5    3067.0       2.0       1.0  1.0     202.0
# 2  04-02-2016       2.5    3067.0       2.0       1.0  0.0     156.0
# 3  04-02-2016       2.5    3067.0       3.0       2.0  1.0       0.0
# ...

# %% [markdown]
# The values in the price column are continious values so price the null values of the price column can be filler by the mean value of the column.

# %%
mean=round(data['Price'].mean())
mean
# Out:
# 1056697.0

# %%
data['Price'].fillna(mean,inplace=True)

# %% [markdown]
# #### 13. Now check the percentage of missing values in each column again, if missing values exist, treat it with the most suitable method.

# %%
for i in data.columns:
    null=round(((data[i].isnull().sum()/data.shape[0])*100),2)
    if null >0:
        print('percentage of null values in',i,'= ',null)
# Out:
# percentage of null values in Suburb =  0.55
# percentage of null values in Address =  0.55
# percentage of null values in Rooms =  0.55
# percentage of null values in Type =  0.55
# percentage of null values in Method =  0.55
# percentage of null values in SellerG =  0.55
# percentage of null values in Date =  0.55
# percentage of null values in Distance =  0.56
# percentage of null values in Postcode =  0.56
# percentage of null values in Bedroom2 =  19.48
# percentage of null values in Bathroom =  19.49
# percentage of null values in Car =  20.09
# percentage of null values in Landsize =  26.47
# percentage of null values in Lattitude =  18.73
# percentage of null values in Longtitude =  18.73
# percentage of null values in Regionname =  0.56
# percentage of null values in Propertycount =  0.56

# %%
for i in data.columns:
    null=round(((data[i].isnull().sum()/data.shape[0])*100),2)
    if null >0:
        if data[i].dtype == 'float64':
            data[i].fillna(data[i].mean(),inplace=True)
            
        if data[i].dtype == 'object':
            data[i].fillna(data[i].mode()[0],inplace=True)

# %%
data.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %% [markdown]
# #### 14. Now since you have completed your data cleaning, determine the number and percentage of columns removed.

# %%
print('Earlier the shape of dataset was',prev.shape,'\nAfter datacleaning procedure the shape becomes',data.shape)
# Out:
# Earlier the shape of dataset was (23678, 21)
# After datacleaning procedure the shape becomes (23678, 18)

# %%
print('Number of column removed= ',prev.shape[1]-data.shape[1])
# Out:
# Number of column removed=  3

# %%
p=round(((1-(data.shape[1]/prev.shape[1]))*100),1)
print('Percentage of column removed= ',p)
# Out:
# Percentage of column removed=  14.3

# %% [markdown]
# #### 15. Determine the number and percentage of rows removed in whole process. Also comment briefly that according to you the amount of data lost is justified or not.

# %%
print('Number of rows removed= ',prev.shape[0]-data.shape[0])
# Out:
# Number of rows removed=  0

# %% [markdown]
# No rows were removed in the process. We were instructed to dropped columns whose null values were higher than 30% and the process column named percentage of null values in BuildingArea,YearBuilt and CouncilArea with null values of 57.69, 51.26, 33.88 percent respectively. So dropping them was a justified move because filling such high values them with their mean or mode put an impact on the variance of the dataset
